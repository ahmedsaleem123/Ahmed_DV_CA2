# %% [markdown]
# **<h1><center>Questions</center></h1>**
#
# 1) A puzzle has multiple ways of reaching the end solution. Fig. 1 shows a graph that represents all possible routes to the solution. The starting point of the game is represented by A, the solution is represented by S. The other points in the graph are possible intermediary stages.
#
# ![image.png](data:image/png;base64,...)
#
#
# (a) The graph in Fig. 1 is a visualisation of the problem.
#
# (i) Identify the differences between a graph and a tree.
#
# (ii) Explain in detail how the graph is an abstraction of the problem.
#
# (iii) Identify the advantages of using a visualisation such as the one shown in Fig. 1.
# <br><br>
# (b) Demonstrate how Dijkstra’s algorithm would find the shortest path to the solution in Fig.1 through diagrams and written explanation of each stage.
# <br><br><br>
# 2) The creator of the puzzle has been told that the A* algorithm is more efficient at finding the shortest path because it uses heuristics. Compare the performance of Dijkstra’s algorithm and the A* search algorithm, referring to heuristics, to find the shortest path to the problem by implementing both algorithms programmatically and comparing the solutions generated in Mark-down. Refer to the complexity of the algorithms and compare the actual time it takes for the solutions to be processed.

# %% [markdown]
# **<h1><center>Answers to Question one (a) </center></h1>**
#
# **i) Identify the differences between a graph and a tree.**<br><br>
# **Ans)** Following are given some major differences between a graph and a tree.<br><br>
#
#  - A graph is a data structure that consists of a set of nodes and a set of edges that connect pairs of nodes, where as, a tree is a special type of graph that is undirected, connected, and has no cycles.
# <br><br>
#  - Edges in a graph can be directed or undirected, where as, all edges in a tree are undirected.
# <br><br>
#  - A node in a graph can have multiple incoming and outgoing edges, where as,a node in a tree can have only one parent node, and zero or more child nodes.
# <br><br>
#  - A graph can have multiple connected components, where as,a tree is always connected.
# <br><br><br><br>
#
# **ii) Explain in detail how the graph is an abstraction of the problem.**
# <br><br>
# **Ans)** The graph in Fig. 1 is an abstraction of the puzzle because it simplifies the problem to its essential elements. The graph does not represent all of the details of the puzzle, such as the specific rules of the puzzle or the specific actions that must be taken to transition between stages. However, the graph does represent the essential structure of the problem, which is the set of possible states of the puzzle and the set of possible transitions between states.
# <br><br>
# Below are given some important points that clearly defines how the graph is an abstraction of the problem:
# <br><br>
#
#  - The nodes in the graph represent the different stages of the puzzle.<br><br>
#  - The edges in the graph represent the possible transitions between stages.<br><br>
#  - The cost of each edge represents the difficulty of transitioning from one stage to another.
# <br><br>
#
# **For example,** the node "B" represents one possible stage of the puzzle. The edge from node "A" to node "B" represents the possible transition from stage "A" to stage "B". The cost of this edge represents the difficulty of transitioning from stage "A" to stage "B".
# <br><br><br><br>
#
# **iii) Identify the advantages of using a visualisation such as the one shown in Fig. 1.**
# <br><br>
# **Ans)** There are many advantages to using a visualisation some of them are given below:<br><br>
#
# 1. **Improved understanding of the problem:** A visualisation can help to improve understanding of the problem by making the problem more concrete and easier to understand.<br><br>
# 2. **Identification of potential solutions:** A visualisation can help to identify potential solutions to the problem by providing a way to explore all of the possible routes to the solution.<br><br>
# 3. **Evaluation of solutions:** A visualisation can help to evaluate potential solutions to the problem by providing a way to compare the different routes to the solution.
# <br><br>
#
# In addition to these general advantages, below are given the specific advantages of visualisation shown in Fig. 1:
# <br><br>
#
# 1. **Improved understanding of the problem:** A visualisation can help to improve understanding of the problem by making the problem more concrete and easier to understand. For example, the graph in Fig. 1 shows all of the possible routes to the solution of the puzzle, which can help to improve understanding of the problem structure.
# <br><br>
# 2. **Identification of potential solutions:** A visualisation can help to identify potential solutions to the problem by providing a way to explore all of the possible routes to the solution. For example, the graph in Fig. 1 can be used to identify all of the possible routes to the solution of the puzzle by starting at the source node and following the edges.
# <br><br>
# 3. **Evaluation of solutions:** A visualisation can help to evaluate potential solutions to the problem by providing a way to compare the different routes to the solution. For example, the graph in Fig. 1 can be used to evaluate different routes to the solution of the puzzle by comparing the costs of the different routes.
#
# <br><br>
#
# Overall, the visualisation shown in Fig. 1 is a valuable tool for solving puzzles. It can help the player to understand the problem, identify potential solutions, and evaluate the different routes to the solution.

# %% [markdown]
# **<h1><center>Answer to Question one (b) </center></h1>**
#
# **b) Demonstrate how Dijkstra’s algorithm would find the shortest path to the solution in Fig.1 through diagrams and written explanation of each stage.**<br><br>
#
# **Ans)**
# <br><br>
# **Stage 1:** If we see given graph, it is partially weighted graph, which means some edges are weighted and some edges are unweighted. So we will consider weight of 0 for those edges that are unweighted. If we see further in graph, we will find that graph contains vertices A through W, but I and O are missing. We have to find the shortest path from starting point A to the solution point S by using Dijkstra's algorithm. If we see A is connected with B at 1 and with c at 0 and with H at 2. We will select minimum A-->C at 0.
# <br><br>![image (1).png](data:image/png;base64,...)
# <br><br>
#
#
# ---
#
#
# **Stage 2:** If we see C is connected with B at 0 and with G at 1, we will select minimum A-->C-->B at 0 + 0 = 0.
# <br><br>
# ![image (02).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 3:** If we see B is connected with D at 4 and with A,C which are already visited but because of the minimum, here we will go back to C and from there to G. Now our path is A-->C-->G at 0 + 1 = 1.
# <br><br>
# ![image (3).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 4:** If we see G is connected with F at 2 and with L at 3, with C which is already visited but because of the minimum, we will go back to A and from there we go to H. Now, our path is A-->H at 2.
# <br><br>
# ![image (4).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 5:** If we see H is connected with K at 5, which J at 9 and with A which is already visited but because of the minimum, we will go to G and from there to F. Now our path is A-->C-->G-->F.
# <br><br>
# ![image (5).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 6:** F is connected with E at 0, with D at 7 and with G which is already visited. We will select minimum e at 0. Now, our path is A-->C-->G-->F-->E.
# <br><br>
# ![image (6).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 7:** If we see E is connected with W at 6, with F which is already visited, with D at 4. But because of the minimum, we will go back to B and from there to D. Now our path is: A-->C-->B-->D.
# <br><br>
# ![image (07).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 8:** D is connected with E,F,B which are already visited, and with L at 7. But because of the shortest path, we will go back to G and from there to L. Now path is: A-->C-->G-->L.
# <br><br>
# ![image (8).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 9:** L is connected with G,D which are already visited and with K at 5 with N at 3 and with M at 4 and with V at 10 and with W at 8. But because of the minimum we will go back to H and from there to K. Now, our path is A-->H-->K.
# <br><br>
# ![image (9).png](data:image/png;base64,...)
# <br><br>
# ---
# **Stage 10:** K is connected with J at 0 and with H,L which are already visited. We will select minimum, A-->H-->K-->J.
# <br><br>
# ![image (10).png](data:image/png;base64,...)
# <br><br>
# **Stage 11:** J is connected with N at 6, with H,K which are already visited. But because of the minimum, we will go back to L and from there to N. Now, our path is: A-->C-->G-->L-->N.
# <br><br>
# ![image (11).png](data:image/png;base64,...)
# <br><br>
# **Stage 12:** N is connected with L,J which are already visited and with S at 7 and with P at 4. But because of min, we go back to L and from there to M. Now our path is: A-->C-->G-->L-->M.
# <br><br>
# ![image (12).png](data:image/png;base64,...)
# <br><br>
# **Stage 13:** M is connected with P at 2 and with Q at 10 and with L which is already visited. But because of min, we go back to E and from there to W. Now our path is: A-->C-->G-->F-->E-->W
# <br><br>
# ![image (013).png](data:image/png;base64,...)
# <br><br>
# **Stage 14:** W is connected with E,L which are already visited, with Q at 4, with V at zero. We will select minimum, which is V at zero, now our path is A-->C-->G-->F-->E-->W-->V.
# <br><br>
# ![image (014).png](data:image/png;base64,...)
# <br><br>
# **Stage 15:** V is connected with U at 3, with S at 6 and with L,W which are already visited. But because of min we go back to M and from there to P. Now our path is: A-->C-->G-->L-->M-->P.
# <br><br>
# ![image (015).png](data:image/png;base64,...)
# <br><br>
#
# **Stage 16:** P is connected with R at 5, with M,N which are all which are already visited. But because of the min we will go back to W and from there to U. Now our path is: A-->C-->G-->F-->E-->W-->V-->U.
#
#
# <br><br>
# ![image (016).png](data:image/png;base64,...)
# <br><br>
# **Stage 17:** U is connected with S at 2, with T at 1, with V which is already visited. But because of the shortest path, we go back to W and from there to Q. Now our path is: A-->C-->G-->F-->E-->W-->Q.
#
# <br><br>
# ![image (017).png](data:image/png;base64,...)
# <br><br>
# **Stage 18:** Q is connected with W,M which are already visited and with S at 8. But because of the min we go back to U and from there to T. Now our path is: A-->C-->G-->F-->E-->W-->V-->U-->T.
# <br><br>
# ![image (018).png](data:image/png;base64,...)
# <br><br>
# **Stage 19:** T is connected with U which is already visited, with R at 3, with S at 0. We will select minimum, which is S at zero, now our path is A-->C-->G-->F-->E-->W-->V-->U-->T-->S.
# <br><br>
# ![image (19).png](data:image/png;base64,...)
# <br><br>
# **Stage 20:** In our pervious stage we have found the shortest path, but R is still unvisited. S is connected with V,U,T,Q,N which are already visited, with R at 4. We will visit R. Now our path is A-->C-->G-->F-->E-->W-->V-->U-->T-->S--R.
# <br><br>
# ![image (20).png](data:image/png;base64,...)
# <br><br>
# **Stage 21:** At this stage, we have visited all the nodes of graph. So the shoetest path we have found is the one in stage 19 which is:  A-->C-->G-->F-->E-->W-->V-->U-->T-->S.
# <br><br>
# ![image (21).png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
#
#
#
#
#
# <br><br>
# **Shortest Distance:** 13
# <br><br>
# **Shortest Path:** A-->C-->G-->F-->E-->W-->V-->U-->T-->S
# <br><br>
